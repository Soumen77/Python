# %%
print(len(78999))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(len(78999))
#
# TypeError: object of type 'int' has no len()

# %%
'Thalapathy vjay'*2
# Out:
# 'Thalapathy vjayThalapathy vjay'

# %%
age=25

# %%
name='pavan'
a_b=10
time=10
_a=5

# %%
sss='Thalapathy vijay'
len(sss)
# Out:
# 16

# %%
sss[3]
# Out:
# 'l'

# %%
sss[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 sss[100]
#
# IndexError: string index out of range

# %%
sss[3,4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 sss[3,4]
#
# TypeError: string indices must be integers, not 'tuple'

# %%
# slicing

# %%
print(sss)
sss[3:5]
# Out:
# Thalapathy vijay
# 'la'

# %%
sss[11:17]
# Out:
# 'vijay'

# %%
sss[6:6999]
# Out:
# 'athy vijay'

# %%
a=25
print(float(a))
print(str(a))
print(bool(a))
# Out:
# 25.0
# 25
# True

# %%
a= 28.5
print(int(a))
print(str(a))
print(bool(a))
# Out:
# 28
# 28.5
# True

# %%
a='ram'
print(int(a))
print(float(a))
# Out:
#   Cell In[16], line 4
#     a: onvertibleToFloat = 2,
#      ^
# SyntaxError: invalid syntax

# %%
# create a program for adding 2 numbers (45,55)

a= 45
b= 55
print(a+b)
sum= a+b
print(sum)
# Out:
# 100
# 100

# %%
# write a program for sum of 2 numbers
x= int(input        e value of x:"))
y= float("Enter the value of y:"))
x+y
# Out:
# 5

# %%
#string formating
x=int(input('Enter a valur for x:'))
y= f

# %%
10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 10/0
#
# ZeroDivisionError: division by zero

# %%
# assign values 5 10 15 to the variables a b c in a single line
a,b,c=(5,10,15)
print(b)
# Out:
# 10

# %%
a=1,2,3
a
# Out:
# (1, 2, 3)

# %%
str='ArithmeticError'
str
# Out:
# 'ArithmeticError'

# %%
str.upper()
# Out:
# 'ARITHMETICERROR'

# %%
str.lower()
# Out:
# 'arithmeticerror'

# %%
str='1hello 3world'

# %%
print(str)
str.title()
# Out:
# 1hello 3world
# '1Hello 3World'

# %%
a='2hello world'
a.capitalize()
# Out:
# '2hello world'

# %%
a.casefold()
# Out:
# '2hello world'

# %%
var='operation'
var.startswith('o')
# Out:
# True

# %%
var.startswith('or')
# Out:
# False

# %%
var.endswith('123')
# Out:
# False

# %%
x='123'
x.isalpha()
# Out:
# False

# %%
x.isdigit()
# Out:
# True

# %%
x.isalnum()
# Out:
# True

# %%
z='abc 123'
z.isalnum()
# Out:
# False

# %%
q='hello world'
q.replace('h','H')
# Out:
# 'Hello world'

# %%
q.replace(' ',',')
# Out:
# 'hello,world'

# %%
q.replace('78','45')
# Out:
# 'hello world'

# %%
q.count('1')
# Out:
# 0

# %%
a='worl is so cruel'
a.split()
# Out:
# ['worl', 'is', 'so', 'cruel']

# %%
x='hello'
x.strip()
# Out:
# 'hello'

# %%
x.upper()
# Out:
# 'HELLO'

# %%
x.lstrip()
# Out:
# 'hello'

# %%
list=['1','2','3','4']
' '.join(list)
# Out:
# '1 2 3 4'

# %%
','.join(list)
# Out:
# '1,2,3,4'

# %%
d=[1,2,3,4]
' '.join(d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 d=[1,2,3,4]
# ----> 2 ' '.join(d)
#
# TypeError: sequence item 0: expected str instance, int found

# %%
x='1234'
#x.reverse()

# %%
x[::-1]
# Out:
# '4321'

# %%
x[::-2]
# Out:
# '42'

# %%
x[::-999]
# Out:
# '4'

# %%
x[1::]
# Out:
# '234'

# %% [markdown]
# Data Structure

# %%
a=1,2,3,True,1.4
type(a)
# Out:
# tuple

# %%
a
# Out:
# (1, 2, 3, True, 1.4)

# %%
a=[1,'2',True,1.4]
print(a)
print(type(a))
# Out:
# [1, '2', True, 1.4]
# <class 'list'>

# %%
x=[1,2,3, 'hello world']
x[3][0:5]
# Out:
# 'hello'

# %%
x[3].upper()
# Out:
# 'HELLO WORLD'

# %%
list=[1,2,3,4]
list.pop(3)
# Out:
# 4

# %%
list
# Out:
# list

# %%
x=('hllo worls')
x[:5]
# Out:
# 'hllo '

# %%
list=[1,2,1,2]
list.remove(2)

# %%
list
# Out:
# [1, 1, 2]

# %%
list=(1,2,4,5,7,9)
list.append()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 list=(1,2,4,5,7,9)
# ----> 2 list.append()
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
s=[]
type(s)
# Out:
# []

# %%
list((2,3,7))
# Out:
# [2, 3, 7]

# %%
str(9)
# Out:
# '9'

# %%
a={}
set(a)
# Out:
# set()

# %%
x={1,2}
y={3,4}
x.union(y)
# Out:
# {1, 2, 3, 4}

# %%
x.intersection(y)
# Out:
# set()

# %%
#convert a list to dict
#and a dict to list to tuple
