# %% [markdown]
# 1. Write a program to check wheather the given number is even or odd

# %%
a=int(input('Enter a number'))
if a%2==0:
    print("Number is Even")
else:
    print("Number is odd")
# Out:
# Number is odd

# %% [markdown]
# 2.Write a program that takes a number and prints whether it is positive, negative, or zero.

# %%
a=int(input("Enter a number"))
if a>0:
    print('Number is possitive')
elif a==0:
    print('Number is Zero')
else:
    print('Number is negetive')
# Out:
# Number is Zero

# %% [markdown]
# 3.Ask the user for their age and check if they are eligible to vote (18 years or older).

# %%
v=int(input("Enter your age"))
if v>18:
    print("You are Eligible for vote")
else:
    print('Your are not not eligible for vote')
# Out:
# You are Eligible for vote

# %% [markdown]
# 4.Extend the previous question to find the largest among three numbers using if-elif-else.

# %%
x,y,z=4,9,5
if x>y and x>z:
    print('x is biggest number')
elif y>x and y>z:
    print('y is biggest number')
else:
    print('z is biggest number')
# Out:
# y is biggest number

# %% [markdown]
# 5.Extend the previous question to find the largest among three numbers using if-elif-else.

# %% [markdown]
# 6.Write a program to check whether a student has passed or failed. (Pass mark is 40).

# %% [markdown]
# 7.Write a program that assigns a grade based on marks:
#
# 90+ → A
#
# 75–89 → B
#
# 50–74 → C
#
# Below 50 → Fail

# %% [markdown]
# 8.Write a program that checks if a year is a leap year.
#
# Leap year if divisible by 4 but not 100, OR divisible by 400.

# %% [markdown]
# 9.Write a program that checks whether a given character is a vowel or consonant.

# %% [markdown]
# 10.Write a program that asks for a username and password. If both match predefined values, print "Login Successful", else print "Access Denied".
