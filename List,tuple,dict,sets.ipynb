# %%
list=[1,2,3,4]

# %%
tuple=(1,2,3,40)

# %%
# () → Tuple, Functions, Expressions ,methods  

# [] → List, Indexing, Comprehensions

# {} → Set, Dictionary

# %%
a=1,2,3

# %%
a=([1,2],[3]) 
type(a)
# Out:
# tuple

# %%
a=[(1,2,3)] 
type(a)
# Out:
# list

# %%
list=(1,2,3)  
list.append()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 2
#       1 list=(1,2,3)
# ----> 2 list.append()
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
# append # insert # remove # pop # clear # extend

# %%
list=1,2,3 
#print(list.sort())

# %%
len(list)
# Out:
# 3

# %%
name='praveen'

# %%
print=[1,2,'array']

# %%
# List append(),insert(),remove(),sort(),pop(),reverse(),extend()
# Out:
# {'abc': 345, 'cab': 6, 'end': 'never'}

# %%
set={1,4,3,6,'abc','acd','adc'}    
print(set)
# Out:
# {1, 3, 4, 6, 'acd', 'abc', 'adc'}

# %%
set.add(90)

# %%
set.remove(6)

# %%
set.pop()
# Out:
# 1

# %%
set
# Out:
# {3, 4, 90, 'abc', 'acd', 'adc'}

# %%
set.clear()

# %%
# tuple len()

# %%
list=([1],['up'])      
type(list)
# Out:
# tuple

# %%
a=2 
b=2 

a==b
# Out:
# True

# %%
a=2 
b=2 

a is b
# Out:
# True

# %%
a=(1,2,3) 
b=[1,2,3] 

a is b
# Out:
# False

# %%
tuple=(1,2,3,4,5) 

tuple.append()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 3
#       1 tuple=(1,2,3,4,5)
# ----> 3 tuple.append()
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
tuple=('kingdom','raja harishchandra')   
tuple.clear()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 2
#       1 tuple=('kingdom','raja harishchandra')
# ----> 2 tuple.clear()
#
# AttributeError: 'tuple' object has no attribute 'clear'

# %%
# equal to =   equals too==

# %%
tuple=()  
print(tuple)
# Out:
# ()

# %%
lisr=[1,2,3,4]  
lisr.insert(1,9999)

# %%
# set add(),remove(),pop(),union()(|),intersection()(&)

# %%
list=[1,'ravi',4,'rahul',4,4,] 
set(list)
# Out:
# {1, 4, 'rahul', 'ravi'}

# %%
set1={1,2,4,5,6}       
print(len(set1))
# Out:
# 5

# %%
set1=[1,2,4,5,6] 
set1.pop()
# Out:
# 6

# %%
set1.add(90)

# %%
set1.remove(2)   
set1
# Out:
# {1}

# %%
set1
# Out:
# {1, 2, 4, 5, 6}

# %%
set1.pop()
# Out:
# 1

# %%
set1.clear()

# %%
set1
# Out:
# set()

# %%
set1={1,2,3} 
set2={4,5,6} 

set1.union(set2)   # |
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
t=tuple()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 t=tuple()
#
# TypeError: 'tuple' object is not callable

# %%
set1.intersection(set2)   # &
# Out:
# set()

# %%
# dict pop(),keys(),values(),update(),items(),get()

# %% [markdown]
# # create a variable named list and keep values 4,5,6 and it has to be a set  as data type
#
#
# # get me the output of none data type
#
# # i have a list [1,2,3]  and at the 90000000th place add 000000009
#
# # cerate an empty dict

# %%
# create a variable names list and keep values 4,5,6 and it has to be a set  as data type
