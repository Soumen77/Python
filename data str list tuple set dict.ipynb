# %%
X=(1,2,'HELLO,world') 
X[2]
# Out:
# 'HELLO,world'

# %%
x='hello world'  
x[:5]
# Out:
# 'hello'

# %%
c=[1,2,'hello world'] 
h=c[2]  
h[:5]
# Out:
# 'hello'

# %%
c=[1,2,'hello world'] 
c[2][:5]
# Out:
# 'hello'

# %%
k=[1,2,(7,8,[1,24,3]),98]   
#k[2][2][1]
k[-1]
# Out:
# 98

# %%
# list

# %%
# append(),insert(),remove(),pop(),extend(),clear()

# %%
list=[1,2,3,4] 
list.remove(4)

# %%
list
# Out:
# [1, 2, 3]

# %%
list.pop()
# Out:
# 3

# %%
list=[1,2,1,2]

# %%
list.append([5,6])    
list
# Out:
# [1, 2, 1, 2, [5, 6]]

# %%
# add 2 values (5,6) 
list.extend([5,6])   
list
# Out:
# [1, 2, 1, 2, [5, 6], 5, 6]

# %%
len(list)
# Out:
# 7

# %%
list.clear() 
list
# Out:
# []

# %%
x=(1,2,3,4) 
x[2]
# Out:
# 3

# %%
x[1:3]
# Out:
# (2, 3)

# %%
x[::-1]
# Out:
# (4, 3, 2, 1)

# %%
x[::-2]
# Out:
# (4, 2)

# %%
x[::-5]
# Out:
# (4,)

# %%
c=(1,2,3,4,4,5)  
c.append()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 2
#       1 c=(1,2,3,4,4,5)
# ----> 2 c.append()
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
c.insert()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 c.insert()
#
# AttributeError: 'tuple' object has no attribute 'insert'

# %%
c.extend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 c.extend()
#
# AttributeError: 'tuple' object has no attribute 'extend'

# %%
c.remove()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 c.remove()
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
c.pop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 c.pop()
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
c.clear()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 c.clear()
#
# AttributeError: 'tuple' object has no attribute 'clear'

# %%
# create an empty list  
x=[] 
type(x)
# Out:
# list

# %%
str(9)
# Out:
# '9'

# %%
list((2,3,7))
# Out:
# [2, 3, 7]

# %%
x=list() 
x
# Out:
# []

# %%
type(x)
# Out:
# list

# %%
len(x)
# Out:
# 0

# %%
x=[1,2,3] 
y=(1,2,3)  
z={1,2,3}

# %%
type(z)
# Out:
# set

# %%
z
# Out:
# {1, 2, 3}

# %%
c={1,6,3,2,'ab','aa',67,44} 
c
# Out:
# {1, 2, 3, 44, 6, 67, 'aa', 'ab'}

# %%
c[3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 c[3]
#
# TypeError: 'set' object is not subscriptable

# %%
c[1:5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 c[1:5]
#
# TypeError: 'set' object is not subscriptable

# %%
c
# Out:
# {1, 2, 3, 44, 6, 67, 'aa', 'ab'}

# %%
c.append()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 c.append()
#
# AttributeError: 'set' object has no attribute 'append'

# %%
c.insert()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 c.insert()
#
# AttributeError: 'set' object has no attribute 'insert'

# %%
c.extend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 c.extend()
#
# AttributeError: 'set' object has no attribute 'extend'

# %%
c.add(999)  
c
# Out:
# {1, 2, 3, 44, 6, 67, 999, 'aa', 'ab'}

# %%
c.remove(67) 
c
# Out:
# {1, 2, 3, 44, 6, 999, 'aa', 'ab'}

# %%
c.pop()
# Out:
# 1

# %%
c
# Out:
# {2, 3, 44, 6, 999, 'aa', 'ab'}

# %%
c.pop(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 c.pop(2)
#
# TypeError: set.pop() takes no arguments (1 given)

# %%
x={1,2,2,3,2}  
x
# Out:
# {1, 2, 3}

# %%
list=[1,2,2,2,23,3,3,4] 
set(list)
# Out:
# {1, 2, 3, 4, 23}

# %%
# create an empty set

# %%
c={} 
type(c)
# Out:
# dict

# %%
c=set()  
type(c)
# Out:
# set

# %%
x={10:[123,12],'key':'value',True:False}     
x
# Out:
# {10: [123, 12], 'key': 'value', True: False}

# %%
x[2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 x[2]
#
# KeyError: 2

# %%
x[10]
# Out:
# [123, 12]

# %%
x[10:True]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 x[10:True]
#
# KeyError: slice(10, True, None)

# %%
x.extend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 x.extend()
#
# AttributeError: 'dict' object has no attribute 'extend'

# %%
x['new key']='new value'  
x
# Out:
# {10: [123, 12], 'key': 'value', True: False, 'new key': 'new value'}

# %%
x.pop(10)
# Out:
# [123, 12]

# %%
x
# Out:
# {'key': 'value', True: False, 'new key': 'new value'}

# %%
v={1:123,1:234,1:345} 
v
# Out:
# {1: 345}

# %%
v={1:123,2:123,3:123} 
v
# Out:
# {1: 123, 2: 123, 3: 123}

# %%
c=678 

del c

# %%
c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 c
#
# NameError: name 'c' is not defined

# %%
x.keys()
# Out:
# dict_keys([10, 'key', True])

# %%
x.values()
# Out:
# dict_values([[123, 12], 'value', False])

# %%
x.items()
# Out:
# dict_items([(10, [123, 12]), ('key', 'value'), (True, False)])

# %%
x=[1,2]
y=[3,4]  
x+y
# Out:
# [1, 2, 3, 4]

# %%
x=(1,2) 
y=(3,4) 
x+y
# Out:
# (1, 2, 3, 4)

# %%
x={1,2} 
y={3,4} 
x.union(y)
# Out:
# {1, 2, 3, 4}

# %%
x.intersection(y)
# Out:
# set()

# %%
# difference  #symmetric_difference

# %%
d1={1:123,2:234}
d2={3:345,4:345} 
d1.update(d2)

# %%
d1
# Out:
# {1: 123, 2: 234, 3: 345, 4: 345}

# %%
x={(1,2,3)}     
type(x)
# Out:
# set

# %%
v=[3,4,[5,('rahul',['x','y',{'name':'manoj','city':'banglore'},'z'],'shivam'),6],6,8] 
v[2][1] [1] [2] ['city']
# Out:
# 'banglore'

# %%
# convert a list to dict 
# and a dict to list  to tuple
